# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7,
    max_tokens=200
)

prompt = "Explain me Langchain in simple terms."

# %%
llm.invoke(prompt).content
# Out:
# "Langchain is a relatively new concept that has gained popularity with the rise of AI and large language models. I'll break it down in simple terms:\n\n**What is Langchain?**\n\nLangchain is a framework that allows you to create applications and tools using large language models (like those from OpenAI, Google, or Meta) in a more flexible and modular way. Think of it like building with Legos: you can connect different language models and tools to create custom workflows and applications.\n\n**How does it work?**\n\nImagine you have a task you want to accomplish, like writing an article or answering a question. With Langchain, you can break down this task into smaller, manageable chunks, and then use different language models to complete each chunk. For example:\n\n1. You ask a language model to generate an outline for your article.\n2. Then, you use another language model to expand on each section of the outline.\n3. Finally, you use a third language model to proofread"

# %%
for chunk in llm.stream(prompt):
    print(chunk.text, end="", flush=True)
# Out:
# Langchain is a relatively new technology that combines the power of large language models (LLMs) with the concept of "chains" or workflows. I'll break it down in simple terms:
#
# **What is Langchain?**
#
# Imagine you have a super-smart assistant (the LLM) that can perform various tasks, like answering questions, generating text, or summarizing content. Langchain is a way to connect multiple tasks or "links" in a chain, allowing the assistant to perform more complex and automated workflows.
#
# **How does it work?**
#
# Here's a simplified example:
#
# 1. You give Langchain a task, like "Plan a trip to Paris."
# 2. Langchain breaks down the task into smaller, manageable chunks, like:
# 	* Find flights to Paris
# 	* Book a hotel
# 	* Research top attractions
# 3. Each chunk is then passed to the LLM, which performs the specific task and generates output (e.g., a list of flights, hotel options

# %%
full = None  # None | AIMessageChunk
for chunk in llm.stream("What color is the sky? Answer in one sentence."):
    full = chunk if full is None else full + chunk
    print(full.text)

# The
# The sky
# The sky is
# The sky is typically
# The sky is typically blue
# ...

# print(full.content_blocks)
# Out:
# The
# The color
# The color of
# The color of the
# The color of the sky
# The color of the sky typically
# The color of the sky typically appears
# The color of the sky typically appears blue
# The color of the sky typically appears blue to
# The color of the sky typically appears blue to the
# The color of the sky typically appears blue to the human
# The color of the sky typically appears blue to the human eye
# The color of the sky typically appears blue to the human eye,
# The color of the sky typically appears blue to the human eye, although
# The color of the sky typically appears blue to the human eye, although it
# The color of the sky typically appears blue to the human eye, although it can
# The color of the sky typically appears blue to the human eye, although it can vary
# The color of the sky typically appears blue to the human eye, although it can vary in
# The color of the sky typically appears blue to the human eye, although it can vary in shade
# The color of the sky typically appears blue to the human eye, although it can vary in shade and
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day,
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions,
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions, and
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions, and other
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions, and other factors
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions, and other factors.
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions, and other factors.
# The color of the sky typically appears blue to the human eye, although it can vary in shade and hue depending on the time of day, atmospheric conditions, and other factors.

# %%
responses = llm.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response.content)
# Out:
# Parrots have colorful feathers for several reasons:
#
# 1. **Communication and Expression**: Colorful feathers help parrots communicate with each other. Different colors can signal emotions, intentions, and even attract a mate. For example, some parrots will display bright colors when they're excited, threatened, or trying to impress a potential mate.
# 2. **Mating and Attraction**: Bright, vibrant feathers can be a key factor in attracting a mate. Parrots with more intense, colorful plumage may be seen as more desirable or healthy, which can give them an advantage in the mating game.
# 3. **Camouflage and Disguise**: While it may seem counterintuitive, some parrots' colorful feathers can actually help them blend in with their surroundings. For example, the bright greens and blues of some parrots can help them merge with the foliage of their rainforest habitats.
# 4. **Warning Signals**: Some parrots have brightly colored feathers that serve as warning signals to potential predators. For
# The wonder of flight! Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation:
#
# **The Four Forces:**
#
# 1. **Lift**: The upward force that opposes the weight of the plane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flows over and under the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force, or lift, that counteracts the weight of the plane.
# 2. **Weight**: The downward force that is the combined weight of the plane, passengers, cargo, and fuel.
# 3. **Thrust**: The forward force that propels the plane through the air. Thrust is created by the plane's engines, which produce a stream of high-speed air that exits
# **Introduction to Quantum Computing**
# =====================================
#
# Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It's a new paradigm for computing that has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.
#
# **Key Concepts**
# ---------------
#
# * **Qubits**: The basic units of quantum information, which can exist in multiple states (0, 1, and both 0 and 1 at the same time) simultaneously.
# * **Superposition**: The ability of qubits to exist in multiple states at the same time, allowing for parallel processing of multiple possibilities.
# * **Entanglement**: The connection between qubits, enabling the instantaneous correlation of their properties, regardless of distance.
# * **Quantum gates**: The quantum equivalent of logic gates in classical computing, used to manipulate qubits and perform operations.
#
# **How Quantum Computing Works**
# -----------------------------
#
# 1. **Preparation

# %%
for response in llm.batch_as_completed([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
]):
    print(response)
# Out:
# (2, AIMessage(content='**Introduction to Quantum Computing**\n=====================================\n\nQuantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.\n\n**Key Concepts**\n---------------\n\n* **Qubits**: Quantum computing uses quantum bits or qubits, which are the fundamental units of quantum information. Qubits are unique because they can exist in multiple states simultaneously, known as a superposition.\n* **Superposition**: Qubits can represent not just 0 or 1, but also any linear combination of 0 and 1, such as 0.5 or 0.25. This property allows qubits to process multiple possibilities simultaneously.\n* **Entanglement**: Qubits can become "entangled," meaning that the state of one qubit is dependent on the state of another qubit, even if they are separated by large distances.\n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 40, 'total_tokens': 240, 'completion_time': 0.436330626, 'completion_tokens_details': None, 'prompt_time': 0.00153078, 'prompt_tokens_details': None, 'queue_time': 0.05149502, 'total_time': 0.437861406}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a008fc-319a-7f50-a1ef-60f594304b05-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 200, 'total_tokens': 240}))
# (1, AIMessage(content="The miracle of flight! Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation:\n\n**The Four Forces:**\n\n1. **Lift**: The upward force that counteracts the weight of the plane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flows over and under the wing, creating an area of lower pressure above the wing and an area of higher pressure below. This pressure difference creates an upward force, or lift, that helps the plane rise into the air.\n2. **Weight**: The downward force that is the combined weight of the plane, passengers, cargo, and fuel. Weight is the force that pulls the plane towards the ground.\n3. **Thrust**: The forward force that propels the plane through the air. Thrust is created by the plane's", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 40, 'total_tokens': 240, 'completion_time': 0.361921791, 'completion_tokens_details': None, 'prompt_time': 0.001174923, 'prompt_tokens_details': None, 'queue_time': 0.049644727, 'total_time': 0.363096714}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a008fc-3197-7f30-86fd-3a9e520b3934-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 200, 'total_tokens': 240}))
# (0, AIMessage(content="Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Expression**: Bright colors help parrots communicate with each other, express emotions, and signal their intentions. Different colors can convey different messages, such as aggression, courtship, or warning calls.\n2. **Mating and Attraction**: Vibrant feathers play a crucial role in attracting a mate. Male parrots often display their brightest colors to impress females and showcase their health, strength, and genetic quality.\n3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural habitats. For example, the bright greens and blues of some parrot species can help them blend in with the foliage and sky, making it harder for predators to spot them.\n4. **Social Status and Dominance**: In some parrot species, colorful feathers can indicate social status or dominance. Birds with more vibrant or elaborate plumage may be seen as more dominant", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 43, 'total_tokens': 243, 'completion_time': 0.587630259, 'completion_tokens_details': None, 'prompt_time': 0.001187112, 'prompt_tokens_details': None, 'queue_time': 0.051139398, 'total_time': 0.588817371}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a008fc-3193-7df1-891e-edd3829ce490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 200, 'total_tokens': 243}))

# %%
import asyncio
response = await llm.ainvoke(prompt)
print(response.content)
# Out:
# Langchain is a framework that allows you to build applications using large language models (like AI chatbots) in a more structured and efficient way. Think of it like a set of tools that helps you connect different language models and other AI components to create more complex and useful applications.
#
# Imagine you're building a robot that can have conversations with people. You would need to connect different parts like:
#
# 1. **Brain (Language Model)**: This is the AI that understands and generates human-like text.
# 2. **Ears (Input)**: This is how the robot receives messages from people.
# 3. **Mouth (Output)**: This is how the robot responds to people.
#
# Langchain helps you connect these parts (and many others) in a flexible and modular way, so you can create more sophisticated applications like:
#
# * Chatbots that can answer questions and have conversations
# * Virtual assistants that can perform tasks and provide information
# * Content generation tools that can create text, images, or videos

# %%
async for chunk in llm.astream(prompt):
    print(chunk.content, end="", flush=True)
# Out:
# Langchain is a relatively new technology that allows you to build applications on top of large language models (LLMs) like chatbots or virtual assistants. In simple terms, Langchain is a framework that helps developers create more complex and interactive systems using these language models.
#
# Here's a breakdown of what Langchain does:
#
# 1. **Large Language Models (LLMs)**: These are AI models trained on vast amounts of text data. They can understand and generate human-like language, but they're limited in their ability to interact with users or remember context.
# 2. **Langchain's Role**: Langchain acts as a bridge between the LLM and the developer. It provides a set of tools and APIs that allow developers to build applications on top of the LLM.
# 3. **Key Features**: Langchain enables features like:
# 	* **Memory**: Langchain allows the LLM to remember context and previous interactions, making it more conversational.
# 	* **Input/Output**: Langchain provides a
