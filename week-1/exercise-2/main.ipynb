# %%
import sys
print(sys.executable)  # sanity check — confirms venv kernel is active

from dotenv import load_dotenv
load_dotenv()
# Out:
# /home/vikas/Coding_play_ground/AI/ai-engineering-learing/.venv/bin/python
# True

# %%
# Example:
# Prompt: "Complete this sentence: The sky is ..."
# The model predicts the next token with probabilities:
# - blue    → 70%
# - clear   → 20%
# - falling → 10%
# - purple  → 5%
# Temperature controls how random the selection is:
# - Low temperature (0.1–0.3): More deterministic and factual outputs.
# - High temperature (0.7–1.5): More diverse and creative outputs.
# top_p (nucleus sampling) controls which predicted tokens are eligible for selection.
# - top_p = 1.0 → Consider all predicted tokens.
# - top_p = 0.1 → Consider only the highest-probability tokens.
# - top_p = 0.9 → Keep adding the most likely tokens until their cumulative
#   probability reaches 90%.
# For top_p = 0.9:
# - blue  = 70% (included)
# - clear = 20% (70% + 20% = 90%, included)
# - Cut off here.
# - "falling" and "purple" are excluded because the cumulative probability
#   threshold has already been reached.
# temperature decide the randomness of the model's output
# low temperature (0.1 - 0.3) = deterministic output (factual), high temperature (0.7 - 1.5) = more random (creativity)

# %%
from langchain_groq import ChatGroq
from langchain_mistralai import ChatMistralAI

groq_model = ChatGroq(
    model="llama-3.3-70b-versatile",
    # temperature decide the randomness of the model's output
    # low temperature (0.1 - 0.3) = deterministic output (factual), high temperature (0.7 - 1.5) = more random (creativity)
    temperature=0.7,
    # top_p controls the diversity of the model's output
    # this decide how many tokens to consider for the output
    # top_p=1.0 means consider all tokens, top_p=0.1 means consider only the most likely tokens
    # E.g top_p=0.7 means consider the top 70% of the most likely tokens
    top_p=0.7,
    # max_tokens controls the maximum number of tokens to generate
    max_tokens=150
)
# Out:
# /home/vikas/Coding_play_ground/AI/ai-engineering-learing/.venv/lib/python3.14/site-packages/pydantic/main.py:263: UserWarning: WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.
#   validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)

# %%
response = groq_model.invoke("Write a one-paragraph story about a robot learning to paint.")

# %%
print(response.content)
# Out:
# As the lights flickered on in the studio, a sleek robot named Zeta whirred to life, its mechanical limbs extending as it approached the canvas. Its creator, a brilliant artist, had programmed Zeta to learn the intricacies of painting, and the robot was eager to begin. With a delicate touch, Zeta dipped its brush into a vibrant shade of blue and began to block out the composition, its advanced sensors and algorithms guiding each stroke. At first, the results were stiff and mechanical, but as the hours passed, Zeta's movements became more fluid, its brushstrokes more expressive. As the sun set, casting a warm glow over the studio, Zeta stepped back to admire its work, a stunning landscape of swirling
